# %%
import sys
sys.path.insert(0, '../')

# %%
import torch

import hiddenlayer as hl
from model import bodypose_model, handpose_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 import torch
# ----> 2 import hiddenlayer as hl
#       3 from model import bodypose_model, handpose_model
#
# ModuleNotFoundError: No module named 'hiddenlayer'

# %%
bodymodel = bodypose_model()
G = visualize_model(bodymodel, torch.zeros([1, 3, 368, 368]))
plt.show()

# %%
handmodel = handpose_model()
hl.build_graph(handmodel, torch.zeros([1, 3, 368, 368]))
